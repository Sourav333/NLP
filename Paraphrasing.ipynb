# %%
pip install git+https://github.com/PrithivirajDamodaran/Parrot_Paraphraser
# Out:
# Collecting git+https://github.com/PrithivirajDamodaran/Parrot_Paraphraser
#   Cloning https://github.com/PrithivirajDamodaran/Parrot_Paraphraser to /tmp/pip-req-build-cej86r2f
#   Running command git clone --filter=blob:none --quiet https://github.com/PrithivirajDamodaran/Parrot_Paraphraser /tmp/pip-req-build-cej86r2f
#   Resolved https://github.com/PrithivirajDamodaran/Parrot_Paraphraser to commit 03084c54b64019ba5fa0b620b9c70ad81123e458
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from parrot==1.0) (4.44.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from parrot==1.0) (0.1.99)
# Collecting python-Levenshtein (from parrot==1.0)
#   Downloading python_Levenshtein-0.25.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting sentence-transformers (from parrot==1.0)
#   Downloading sentence_transformers-3.1.0-py3-none-any.whl.metadata (23 kB)
# Collecting fuzzywuzzy (from parrot==1.0)
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Collecting Levenshtein==0.25.1 (from python-Levenshtein->parrot==1.0)
#   Downloading Levenshtein-0.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting rapidfuzz<4.0.0,>=3.8.0 (from Levenshtein==0.25.1->python-Levenshtein->parrot==1.0)
#   Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->parrot==1.0) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->parrot==1.0) (2.4.0+cu121)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->parrot==1.0) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->parrot==1.0) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->parrot==1.0) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->parrot==1.0) (0.24.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->parrot==1.0) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->parrot==1.0) (3.16.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers->parrot==1.0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->parrot==1.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->parrot==1.0) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->parrot==1.0) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->parrot==1.0) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->parrot==1.0) (0.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers->parrot==1.0) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers->parrot==1.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers->parrot==1.0) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers->parrot==1.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers->parrot==1.0) (3.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->parrot==1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->parrot==1.0) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->parrot==1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->parrot==1.0) (2024.8.30)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers->parrot==1.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers->parrot==1.0) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers->parrot==1.0) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers->parrot==1.0) (1.3.0)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Downloading python_Levenshtein-0.25.1-py3-none-any.whl (9.4 kB)
# Downloading Levenshtein-0.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 8.2 MB/s eta 0:00:00
# Downloading sentence_transformers-3.1.0-py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.1/249.1 kB 17.2 MB/s eta 0:00:00
# Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 46.0 MB/s eta 0:00:00
# Building wheels for collected packages: parrot
#   Building wheel for parrot (setup.py) ... done
#   Created wheel for parrot: filename=parrot-1.0-py3-none-any.whl size=8590 sha256=331ab7b919cd8b5f40a1d3afae936b95a712345fa668751c1cdd11327f20fdb6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pc6w6s38/wheels/1a/d7/c8/65dd3cd3d494b269c1ccdb0a88affc1a08d559d84324bf3b2b
# Successfully built parrot
# Installing collected packages: fuzzywuzzy, rapidfuzz, Levenshtein, python-Levenshtein, sentence-transformers, parrot
# Successfully installed Levenshtein-0.25.1 fuzzywuzzy-0.18.0 parrot-1.0 python-Levenshtein-0.25.1 rapidfuzz-3.9.7 sentence-transformers-3.1.0

# %%
from parrot import Parrot
import torch
import warnings
warnings.filterwarnings("ignore")

# %%
def random_state(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

random_state(1234)

# %%
parrot = Parrot(model_tag="prithivida/parrot_paraphraser_on_T5", use_gpu=False)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.89k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.37k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/913 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/476 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.78k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/686 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
phrases = ["For route 7, list the transit trips that experience the longest average delays?",
           "List the top 10 stops with the highest average delays and include the number of trips for each transit stop?"
            "Identify road segments where service reliability for transit is low?",
           "How can service disruptions in transit be detected and analyzed effectively?"
]

# %%
for phrase in phrases:
  print("-"*100)
  print("Input_phrase: ", phrase)
  print("-"*100)
  para_phrases = parrot.augment(input_phrase=phrase)
  for para_phrase in para_phrases:
   print(para_phrase)
# Out:
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  For route 7, list the transit trips that experience the longest average delays?
# ----------------------------------------------------------------------------------------------------
# ('list the transit trips with the longest average delay?', 39)
# ('which transit route experiences the longest average delay?', 39)
# ('list the transit trips that have the longest average delays?', 33)
# ('list the transit trips that experience the longest average delays?', 24)
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  List the top 10 stops with the highest average delays and include the number of trips for each transit stop?Identify road segments where service reliability for transit is low?
# ----------------------------------------------------------------------------------------------------
# ('list the 10 stops with the most average delays and include the number of trips for each transit stop?identify road segments where service reliability is low for transit?', 35)
# ('list the top 10 stops with the highest average delays and include the number of trips for each transit stop?identify road segments where service reliability is low for transit?', 26)
# ('list the top 10 stops with the highest average delay and include the number of trips for each transit stop? identify road segments where service reliability for transit is low?', 14)
# ('list the top 10 stops with the highest average delays and include the number of trips for each transit stop? identify road segments where service reliability for transit is low', 14)
# ('list the top 10 stops with the highest average delays and include the number of trips for each transit stop?identify road segments where service reliability for transit is low', 13)
# ('list the top 10 stops with the highest average delays and include the number of trips for each transit stop?identify road segments where service reliability for transit is low?', 12)
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  How can service disruptions in transit be detected and analyzed effectively?
# ----------------------------------------------------------------------------------------------------
# ('how can we detect service disruption in transit?', 54)
# ('how do we detect service disruptions in transit?', 53)
# ('how does transit service disruptions get detected and analyzed?', 41)
# ('how do service interruptions in transit be detected and analyzed effectively?', 20)
# ('how can a service interruption in transit be detected and analyzed effectively?', 20)
