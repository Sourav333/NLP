# %%
# !pip install --upgrade langchain -q

# %%
pip install openai==0.28

# %%
import os
os.environ["OPENAI_API_KEY"] = ""

# %%
# !pip install unstructured -q
# !pip install unstructured[local-inference]
# !pip install detectron2@git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2 -q
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 13.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done

# %%
# !apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.5).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# !pip install -U langchain-community

# %%
from langchain.document_loaders import DirectoryLoader

directory = '/content/data'

def load_docs(directory):
  loader = DirectoryLoader(directory)
  documents = loader.load()
  return documents

documents = load_docs(directory)
len(documents)
# Out:
# 1

# %%
# !pip install nltk

# %%
# !pip install "unstructured[pdf]"

# %%
# !sudo apt-get install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# ...

# %%
import nltk
from langchain.document_loaders import DirectoryLoader
import pytesseract
pytesseract.pytesseract.tesseract_cmd = '/usr/bin/tesseract' # Replace with the actual path

nltk.download('punkt')

directory = '/content/data'

def load_docs(directory):
  loader = DirectoryLoader(directory)
  documents = loader.load()
  return documents

documents = load_docs(directory)
len(documents)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ERROR:langchain_community.document_loaders.directory:Error loading file /content/data/combined_text_content.txt
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-4853423e903b> in <cell line: 15>()
#      13   return documents
#      14
# ---> 15 documents = load_docs(directory)
#      16 len(documents)
#
# <ipython-input-2-4853423e903b> in load_docs(directory)
#      10 def load_docs(directory):
#      11   loader = DirectoryLoader(directory)
# ---> 12   documents = loader.load()
#      13   return documents
#      14
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_loaders/directory.py in load(self)
#     115     def load(self) -> List[Document]:
#     116         """Load documents."""
# ...

# %%
import nltk

# !pip install nltk --upgrade # ensures that the latest version of NLTK is installed
nltk.download('punkt') # downloads the 'punkt' resource which includes the necessary tokenizer data
from langchain.document_loaders import DirectoryLoader
import pytesseract
pytesseract.pytesseract.tesseract_cmd = '/usr/bin/tesseract' # Replace with the actual path




directory = '/content/data'

def load_docs(directory):
  loader = DirectoryLoader(directory)
  documents = loader.load()
  return documents

documents = load_docs(directory)
len(documents)
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 1

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
def split_docs(documents,chunk_size=1000,chunk_overlap=20):
  text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
  docs = text_splitter.split_documents(documents)
  return docs

docs = split_docs(documents)
print(len(docs))
# Out:
# 530

# %%
print(docs[5].page_content)
# Out:
# will wait for page to reach the load state prior to moving forward. Learn more about the page.goto() options. Interactions​ Performing actions starts with locating the elements. Playwright uses Locators API for that. Locators represent a way to find element(s) on the page at any moment, learn more about the different types of locators available. Playwright will wait for the element to be actionable prior to performing the action, so there is no need to wait for it to become available.

# %% [markdown]
# #requires for openai embedding

# %%
# !pip install tiktoken -q

# %%
import openai
from langchain.embeddings.openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings()

query_result = embeddings.embed_query("Hello world")
len(query_result)
# Out:
# 1536

# %%
query_result
# Out:
# [-0.004782061775575981,
#  0.004832498948880666,
#  -0.01648030318721954,
#  -0.024499791856582992,
#  -0.017388169512736022,
#  0.012634479083701404,
#  -0.01921651227200245,
#  0.009293024850584886,
#  -0.010219805407128945,
#  -0.02678206870993028,
#  0.02288580789876877,
#  0.010320679753738316,
#  -0.023629753993121658,
#  -0.006582033653962355,
#  0.008076231362446179,
#  0.0025250044402036543,
#  0.025067209474184067,
#  -0.01210488992815548,
#  0.013151458131013866,
#  0.01336581600114345,
#  -0.01068634774679803,
#  -0.003502221937221743,
#  0.0038868043941396877,
#  0.008366244294040828,
#  -0.020754843030996846,
#  -0.0018882366988389192,
#  0.012319246866962449,
#  -0.018976936979373794,
#  0.030665721275503564,
#  -0.03127096735515979,
#  0.0036882086936406203,
#  -0.007748390434457687,
#  -0.006083967906354851,
#  -0.017791666899173504,
#  0.004920763652917884,
#  -0.015635483677579894,
#  0.001406720554134561,
#  -0.015635483677579894,
#  0.019758711535781834,
# ...

# %%
# !pip install pinecone-client -q

# %%
from pinecone import Pinecone, ServerlessSpec
from langchain.vectorstores import Pinecone as LangChainPinecone

# Define your index name
index_name = "docupload"

# Initialize Pinecone using the new API
pc = Pinecone(
    api_key="80db1ef6-d771-4ab1-8af1-27e0fcfcee94",  # Your Pinecone API key
)

# Check if the index exists; if not, create it
if index_name not in pc.list_indexes().names():
    pc.create_index(
        name=index_name,
        dimension=1536,  # Adjust dimension based on your embeddings model
        metric='euclidean',  # You can change this metric if needed
        spec=ServerlessSpec(
            cloud='aws',  # Cloud provider
            region='us-east-1'  # Your desired region
        )
    )

# Access the Pinecone index
index = pc.Index(index_name)  # Use pc.Index to get the index object

# Use LangChain's Pinecone wrapper to interface with Pinecone and LangChain
langchain_index = LangChainPinecone(
    index,  # Pinecone index object
    embeddings,  # Embeddings model
    text_key="text"  # Specify the key for the document text
)

# Add documents to the index using LangChain Pinecone
# Make sure to call `from_documents` correctly
langchain_index.from_documents(docs,embeddings)
# Out:
# ---------------------------------------------------------------------------
# PineconeConfigurationError                Traceback (most recent call last)
# <ipython-input-35-f0bd018090db> in <cell line: 36>()
#      34 # Add documents to the index using LangChain Pinecone
#      35 # Make sure to call `from_documents` correctly
# ---> 36 langchain_index.from_documents(docs,embeddings)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/vectorstores/base.py in from_documents(cls, documents, embedding, **kwargs)
#     828         texts = [d.page_content for d in documents]
#     829         metadatas = [d.metadata for d in documents]
# --> 830         return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#     831
#     832     @classmethod
#
# ...

# %%
from pinecone import Pinecone
pinecone = Pinecone(
    api_key="80db1ef6-d771-4ab1-8af1-27e0fcfcee94",
    environment="us-east-1-aws"
)

index_name="docupload"

# %%
pip install --upgrade langchain-pinecone

# %%
from langchain_pinecone import PineconeVectorStore
PineconeVectorStore.from_documents(
        docs,
        index_name=index_name,
        embedding=embeddings
    )
# Out:
# ---------------------------------------------------------------------------
# PineconeConfigurationError                Traceback (most recent call last)
# <ipython-input-21-7eb4f0eb737d> in <cell line: 2>()
#       1 from langchain_pinecone import PineconeVectorStore
# ----> 2 PineconeVectorStore.from_documents(
#       3         docs,
#       4         index_name=index_name,
#       5         embedding=embeddings
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/vectorstores/base.py in from_documents(cls, documents, embedding, **kwargs)
#     828         texts = [d.page_content for d in documents]
#     829         metadatas = [d.metadata for d in documents]
# --> 830         return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#     831
#     832     @classmethod
#
# ...

# %%
# !pip install langchain-pinecone

from langchain_pinecone import PineconeVectorStore
import os

# Set the Pinecone API key as an environment variable
os.environ["PINECONE_API_KEY"] = "80db1ef6-d771-4ab1-8af1-27e0fcfcee94"
os.environ["PINECONE_ENVIRONMENT"] = "us-east-1-aws"

vectorstore= PineconeVectorStore.from_documents(
    docs,
    index_name=index_name,
    embedding=embeddings
)

# %%
def get_similiar_docs(query,k=2,score=False):
  if score:
    similar_docs = index.similarity_search_with_score(query,k=k)
  else:
    similar_docs = index.similarity_search(query,k=k)
  return similar_docs

query = "what is playwright"
similar_docs = get_similiar_docs(query)
similar_docs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-77319a814dc4> in <cell line: 9>()
#       7
#       8 query = "what is playwright"
# ----> 9 similar_docs = get_similiar_docs(query)
#      10 similar_docs
#
# <ipython-input-61-77319a814dc4> in get_similiar_docs(query, k, score)
#       3     similar_docs = index.similarity_search_with_score(query,k=k)
#       4   else:
# ----> 5     similar_docs = index.similarity_search(query,k=k)
#       6   return similar_docs
#       7
#
# NameError: name 'index' is not defined

# %%
from pickle import TRUE
def get_similiar_docs(query,k=2,score=False):
  if score:
    # Use similarity_search_with_score on the vectorstore object
    similar_docs = vectorstore.similarity_search_with_score(query,k=k)
  else:
    # Use similarity_search on the vectorstore object
    similar_docs = vectorstore.similarity_search(query,k=k)
  return similar_docs

query = "what is annotation"
similar_docs = get_similiar_docs(query,k=3,score=TRUE)
similar_docs
# Out:
# [(Document(id='dcc0f829-115c-4e97-bd52-d320c65585ac', metadata={'source': '/content/data/combined_text_content.txt'}, page_content='Annotations | Playwright'),
#   0.805873811),
#  (Document(id='f914b212-99a5-4415-ae8c-65c73f80da50', metadata={'source': '/content/data/combined_text_content.txt'}, page_content='Annotations | Playwright'),
#   0.805873811),
#  (Document(id='14b99e73-94e7-4343-9077-17a38beddbfe', metadata={'source': '/content/data/combined_text_content.txt'}, page_content='Annotations | Playwright'),
#   0.805873811)]

# %%
from langchain.llms import OpenAI
model_name = "gpt-3.5-turbo"
llm = OpenAI(model_name=model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_community/llms/openai.py:254: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain_community.chat_models import ChatOpenAI`
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-2-01655626fd20> in <cell line: 3>()
#       1 from langchain.llms import OpenAI
#       2 model_name = "gpt-3.5-turbo"
# ----> 3 llm = OpenAI(model_name=model_name)
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/llms/openai.py in __new__(cls, **data)
#     257                 "`from langchain_community.chat_models import ChatOpenAI`"
#     258             )
# --> 259             return OpenAIChat(**data)
#     260         return super().__new__(cls)
#     261
#
# ...

# %%
from langchain.chains.question_answering import load_qa_chain
chain = load_qa_chain(llm, chain_type="stuff")

def get_answer(query):
  similar_docs = get_similiar_docs(query)
  print(similar_docs)
  answer = chain.run(input_documents=similar_docs, question=query)
  return answer

query = "what is playwright"
get_answer(query)
# Out:
# [Document(id='3846b8d8-4a64-4242-8ccf-f5367262c114', metadata={'source': '/content/data/combined_text_content.txt'}, page_content='Pages | Playwright'), Document(id='8deab438-db4f-4017-9959-d8825ea93da3', metadata={'source': '/content/data/combined_text_content.txt'}, page_content='Pages | Playwright')]
# ' A playwright is a person who writes plays.'

# %%
query = "what is annotation"
print(similar_docs)
get_answer(query)
# Out:
# [(Document(id='dcc0f829-115c-4e97-bd52-d320c65585ac', metadata={'source': '/content/data/combined_text_content.txt'}, page_content='Annotations | Playwright'), 0.805873811), (Document(id='f914b212-99a5-4415-ae8c-65c73f80da50', metadata={'source': '/content/data/combined_text_content.txt'}, page_content='Annotations | Playwright'), 0.805873811), (Document(id='14b99e73-94e7-4343-9077-17a38beddbfe', metadata={'source': '/content/data/combined_text_content.txt'}, page_content='Annotations | Playwright'), 0.805873811)]
# [Document(id='14b99e73-94e7-4343-9077-17a38beddbfe', metadata={'source': '/content/data/combined_text_content.txt'}, page_content='Annotations | Playwright'), Document(id='dcc0f829-115c-4e97-bd52-d320c65585ac', metadata={'source': '/content/data/combined_text_content.txt'}, page_content='Annotations | Playwright')]
# ...
